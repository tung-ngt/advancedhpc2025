# %%
# !pip install numba-cuda==0.4.0 numba==0.60 llvmlite==0.43
# Out:
# Collecting numba-cuda==0.4.0
#   Downloading numba_cuda-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: numba==0.60 in /usr/local/lib/python3.12/dist-packages (0.60.0)
# Requirement already satisfied: llvmlite==0.43 in /usr/local/lib/python3.12/dist-packages (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.12/dist-packages (from numba==0.60) (2.0.2)
# Downloading numba_cuda-0.4.0-py3-none-any.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: numba-cuda
#   Attempting uninstall: numba-cuda
#     Found existing installation: numba-cuda 0.11.0
#     Uninstalling numba-cuda-0.11.0:
#       Successfully uninstalled numba-cuda-0.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires numba-cuda<0.12.0a0,>=0.11.0, but you have numba-cuda 0.4.0 which is incompatible.
# Successfully installed numba-cuda-0.4.0

# %%
import numba.cuda

# %%
from numba import config
config.CUDA_ENABLE_PYNVJITLINK = 1

# %%
numba.cuda.detect()
# Out:
# Found 1 CUDA devices
# id 0             b'Tesla T4'                              [SUPPORTED]
#                       Compute Capability: 7.5
#                            PCI Device ID: 4
#                               PCI Bus ID: 0
#                                     UUID: GPU-6f631847-f312-0475-aea5-f7279df2b0d6
#                                 Watchdog: Disabled
#              FP32/FP64 Performance Ratio: 32
# Summary:
# 	1/1 devices are supported
# True

# %%
device = numba.cuda.select_device(0)
print("name:", device.name)

free_bytes, total_bytes = numba.cuda.current_context().get_memory_info()
print("total mem:", total_bytes)
print("free mem:", free_bytes)
print("multiprocessor count:", device.MULTIPROCESSOR_COUNT)
print("compute capability:", device.compute_capability)

# compute capability 7.5 has 64 cores per processor
core_count = device.MULTIPROCESSOR_COUNT * 64
print("core count:", core_count)
# Out:
# name: b'Tesla T4'
# total mem: 15828320256
# free mem: 15720382464
# multiprocessor count: 40
# compute capability: (7, 5)
# core count: 2560

# %%
import numpy as np
from matplotlib import pyplot as plt
import urllib
from PIL import Image
import math
import time

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Cat_August_2010-4.jpg/1200px-Cat_August_2010-4.jpg"
image = np.array(Image.open(urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"}))))
plt.imshow(image)
print(image.shape)
# Out:
# (734, 1200, 3)

# %%
@numba.cuda.jit
def gray_1d(src, dst):
  x = numba.cuda.threadIdx.x + numba.cuda.blockIdx.x * numba.cuda.blockDim.x
  if x < src.shape[0]:
    value = (src[x, 0] + src[x, 1] + src[x, 2]) / 3
    dst[x, 0] = value
    dst[x, 1] = value
    dst[x, 2] = value

# %%
block_size = 1024
flatten = image.reshape(-1, image.shape[-1])
grid_size = math.ceil(flatten.shape[0] / block_size)

src = numba.cuda.to_device(flatten)
dst = numba.cuda.device_array(flatten.shape, image.dtype)
gray_1d[grid_size, block_size](src, dst)
output_image = dst.copy_to_host()
output_image = output_image.reshape(image.shape)
plt.imshow(output_image)

# %%
flatten = image.reshape(-1, image.shape[-1])

src = numba.cuda.to_device(flatten)
dst = numba.cuda.device_array(flatten.shape, image.dtype)


ds = []
for i in range(1, 1024 + 1):
  block_size = i
  grid_size = math.ceil(flatten.shape[0] / block_size)
  d = 0
  for _ in range(1000):
    start = time.time()
    gray_1d[grid_size, block_size](src, dst)
    end = time.time()
    d += end - start
  d /= 10
  ds.append(d)

# %%
plt.plot(np.arange(1, 1024+1, 1), ds)
plt.ylabel("Execution time (second)")
plt.xlabel("Number of threads per block")
# Out:
# Text(0.5, 0, 'Number of threads per block')

# %%
def gray_cpu(src, dst):
  for x in range(src.shape[0]):
    for y in range(src.shape[1]):
      value = (src[x, y, 0] + src[x, y, 1] + src[x, y, 2]) // 3
      dst[x, y, 0] = value
      dst[x, y, 1] = value
      dst[x, y, 2] = value

# %%
start = time.time()
dst = np.zeros(image.shape, image.dtype)
gray_cpu(image.astype(np.float32), dst)
end = time.time()
print(end - start)
# Out:
# 1.1662275791168213
